# %%
import os
import openai
import json
from tqdm.notebook import tqdm
import numpy as np
from openai import AsyncOpenAI
import re
from PIL import Image
from pprint import pprint
import warnings
from dotenv import load_dotenv
load_dotenv()


# %matplotlib inline
warnings.filterwarnings('ignore', category=UserWarning, module='pandas')

# initialize openai
openai.api_key = os.environ["OPENAI_API_KEY"]

# %% [markdown]
# - 이미지 cosine similarity
# - 이미지 description
# 	- intro to meta data
# 		- furniture의 개수 등을 기준으로 filter
# - 사진들간의 cosine similarity
# 	- types of furniture

# %% [markdown]
# ### 데이터 load

# %% [markdown]
# - `img_path` : 이미지 path
# - `img_descriptions` : GPT-4V가 생성한 이미지에 대한 설명
# - `furniture_paths` : YOLO가 detect한 가구들의 이미지 path
# - `furniture_descriptions` : YOLO가 detect한 가구들

# %%
img_paths = list(os.walk('../data/room-dataset/living'))[0][2]
img_paths = [i for i in img_paths if i!=".DS_Store"]
img_paths = [i for i in img_paths if int(i.split('_')[1].split('.')[0]) in list(range(1, 101))]

def extract_number(filename):
    match = re.search(r'\d+', filename)
    return int(match.group()) if match else 0

img_paths = sorted(img_paths, key=extract_number)
# img_paths = [os.path.join('../data/room-dataset/living', i) for i in img_paths]
img_paths = [str('../data/room-dataset/living/' + str(i)) for i in img_paths]


# img_paths[:10]

# %%
with open("../data/room-dataset/room_descriptions_parsed.json", 'r') as file:
    img_descriptions = json.load(file)

img_descriptions['living_100.jpg']
# Out:
# {'Color Scheme': 'The color scheme is predominantly neutral, with rich brown leather sofas complementing the dark-wood floor. Hints of black are seen in the frames and furnishings, while the off-white drapes and rug incorporate lighter tones, providing contrast and visual balance.',
#  'Lighting': 'Natural lighting from the large, floor-to-ceiling windows illuminates the room, casting dynamic shadows on the floor and highlighting the building’s facade outside. No artificial light sources are visible in the image.',
#  'Spatial Layout': 'The room has a minimalist layout with a symmetrical arrangement of armchairs and a sofa centered around a round, copper-toned coffee table. There’s a sense of openness around the seating arrangement, emphasizing space and structure.',
#  'Architectural Features': 'The room boasts a soaring ceiling and industrial-style floor-to-ceiling windows that frame an urban landscape, while the exposed wooden beams on the ceiling provide a rustic touch. The large paneled window becomes a focal point, offering expansive views and connecting the interior to the cityscape.'}

# %%
furniture_paths = list(os.walk('../data/room-dataset/living_cropped'))[0][2]
furniture_paths = [i for i in furniture_paths if i!=".DS_Store"]
# furniture_paths = [os.path.join('../data/room-dataset/living_cropped', i) for i in furniture_paths]
furniture_paths = [str('../data/room-dataset/living_cropped/' + str(i)) for i in furniture_paths]

# furniture_paths[:10]

# %%
with open("../data/room-dataset/room_detections_parsed.json", 'r') as file:
    furniture_descriptions = json.load(file)

furniture_descriptions['../data/room-dataset/living/living_1.jpg']
# Out:
# {'boxes': [[0.0, 646.0740966796875, 173.80274963378906, 852.3871459960938],
#   [428.7904968261719, 649.98583984375, 622.0, 855.7733764648438],
#   [420.5445251464844, 803.3565673828125, 621.3555297851562, 930.150146484375],
#   [0.0, 793.6344604492188, 201.38124084472656, 930.3408813476562],
#   [13.38364315032959, 604.041015625, 103.91728973388672, 668.1535034179688]],
#  'scores': [0.9133118391036987,
#   0.9028496742248535,
#   0.7879153490066528,
#   0.7175205945968628,
#   0.6018742918968201],
#  'categories': [57.0, 57.0, 56.0, 56.0, 56.0],
#  'labels': ['couch', 'couch', 'chair', 'chair', 'chair']}

# %%
# Image.open(img_paths[10])

# %%
pprint(img_descriptions['living_11.jpg'])
# Out:
# {'Architectural Features': 'Architectural elements include large '
#                            'floor-to-ceiling windows that provide an '
#                            'unobstructed view of the outdoor scenery, a '
#                            'sizable stone fireplace as the focal point, an '
#                            'exposed wood ceiling with modern beams, and a '
#                            'steel and wood staircase with a glass balustrade '
#                            'leading to an upper floor.',
#  'Color Scheme': 'The room employs a natural and neutral color palette, with '
#                  'the dominant hues being the warm browns of the wood ceiling '
#                  'and floor, complemented by the cool grey of the stone '
#                  'fireplace. Beige walls and furniture provide a neutral '
#                  'backdrop, while green accents from plants and the outside '
#                  'view add a touch of color.',
#  'Lighting': 'The room has ample natural lighting from the large windows, '
#              'creating a well-lit space during the daytime. The combination of '
#              'natural light with the warm, soft artificial light from the wall '
#              "sconces, lamp, and stairwell pendants enhances the room's cozy "
#              'and welcoming atmosphere.',
#  'Spatial Layout': 'The living area features an open-plan layout that '
#                    'seamlessly transitions into the adjoining rooms without '
#                    'barriers. The furniture is arranged to create distinct '
#                    'areas for conversation around the fireplace and for music '
#                    'by the piano, promoting social interaction while also '
#                    'offering an inviting passageway to the balcony.'}

# %%
furniture_descriptions['../data/room-dataset/living/living_11.jpg']
# Out:
# {'boxes': [[1134.7818603515625,
#    978.6834716796875,
#    1509.1383056640625,
#    1185.5596923828125],
#   [121.5030746459961, 991.958740234375, 468.4966125488281, 1344.454345703125],
#   [254.2671661376953, 927.840087890625, 429.0323486328125, 1150.62646484375],
#   [643.4228515625, 1161.3983154296875, 1640.185791015625, 1583.6246337890625]],
#  'scores': [0.8340874910354614,
#   0.7747324109077454,
#   0.773466169834137,
#   0.6170129179954529],
#  'categories': [57.0, 56.0, 56.0, 57.0],
#  'labels': ['couch', 'chair', 'chair', 'couch']}

# %%
from utils import draw_images

# draw_images([Image.open(i) for i in furniture_paths if 'living_11' in i])

# %% [markdown]
# ---

# %% [markdown]
# ### 1. 이미지 전체의 cosine similarity를 활용한 유사한 이미지 탐색

# %% [markdown]
# #### < DB 구축 >
# - CLIP을 활용하여 이미지들을 Image embedding vector로 변환 (01.Image search.ipynb 참고)
#
# #### < Search >
# - Input image도 마찬가지로 Image embedding vector로 변환
# - DB와 cosine similarity 유사도를 기반으로 search

# %% [markdown]
# 1-1. DB 구축

# %%
from transformers import CLIPProcessor, CLIPModel
from utils import extract_img_features, search_image

model_name = "openai/clip-vit-base-patch32"
clip_model = CLIPModel.from_pretrained(model_name)
clip_processor = CLIPProcessor.from_pretrained(model_name)

# %%
image_features = [extract_img_features(Image.open(i), clip_processor, clip_model) for i in img_paths]

# %%
import pandas as pd

# %%
df = pd.DataFrame({"img_path":img_paths, "img_emb":image_features})
df['img_name'] = df['img_path'].str.split('/').str[-1]
df.head()
# Out:
#                                    img_path  \
# 0  ../data/room-dataset/living/living_1.jpg
# 1  ../data/room-dataset/living/living_2.jpg
# 2  ../data/room-dataset/living/living_3.jpg
# 3  ../data/room-dataset/living/living_4.jpg
# 4  ../data/room-dataset/living/living_5.jpg
#
#                                              img_emb      img_name
# 0  [[tensor(0.5824), tensor(-0.3086), tensor(0.04...  living_1.jpg
# 1  [[tensor(0.1654), tensor(0.1498), tensor(0.052...  living_2.jpg
# 2  [[tensor(0.1472), tensor(0.0983), tensor(0.261...  living_3.jpg
# 3  [[tensor(0.4033), tensor(-0.0663), tensor(-0.0...  living_4.jpg
# 4  [[tensor(0.7429), tensor(-0.4593), tensor(-0.0...  living_5.jpg

# %%
query_image = Image.open("../data/room-dataset/living/living_212.jpg")
# query_image

# %% [markdown]
# 1-2. Search

# %%
from sklearn.metrics.pairwise import cosine_similarity

def search_similar_vector(query_feature, features):
    """
    주어진 vector들과 비교하여, query_feature와 유사한 vector의 index와 유사도를 제공함

    Args:
        query_feature (np.array): input embedding vector
        features (List[np.array]): embedding vector들의 list

    Returns:
        Tuple[np.array, np.array]: 유사한 embedding vector들의 index & cosine similarity
    """
    features_stack = np.vstack(features)
    similarities = cosine_similarity([np.array(query_feature)], features_stack).flatten()

    return similarities

# %%
df['clip_similarities'] = search_similar_vector(extract_img_features(query_image, clip_processor, clip_model)[0], df.img_emb.tolist())

# %%
df.head()
# Out:
#                                    img_path  \
# 0  ../data/room-dataset/living/living_1.jpg
# 1  ../data/room-dataset/living/living_2.jpg
# 2  ../data/room-dataset/living/living_3.jpg
# 3  ../data/room-dataset/living/living_4.jpg
# 4  ../data/room-dataset/living/living_5.jpg
#
#                                              img_emb      img_name  \
# 0  [[tensor(0.5824), tensor(-0.3086), tensor(0.04...  living_1.jpg
# 1  [[tensor(0.1654), tensor(0.1498), tensor(0.052...  living_2.jpg
# 2  [[tensor(0.1472), tensor(0.0983), tensor(0.261...  living_3.jpg
# 3  [[tensor(0.4033), tensor(-0.0663), tensor(-0.0...  living_4.jpg
# 4  [[tensor(0.7429), tensor(-0.4593), tensor(-0.0...  living_5.jpg
#
#    clip_similarities
# 0           0.811182
# 1           0.868923
# 2           0.853854
# 3           0.842833
# 4           0.814352

# %%
top5 = df.nlargest(5, 'clip_similarities')

# %%
top5
# Out:
#                                      img_path  \
# 35  ../data/room-dataset/living/living_36.jpg
# 26  ../data/room-dataset/living/living_27.jpg
# 39  ../data/room-dataset/living/living_40.jpg
# 18  ../data/room-dataset/living/living_19.jpg
# 8    ../data/room-dataset/living/living_9.jpg
#
#                                               img_emb       img_name  \
# 35  [[tensor(0.4040), tensor(0.3932), tensor(0.015...  living_36.jpg
# 26  [[tensor(0.1179), tensor(0.1084), tensor(0.061...  living_27.jpg
# 39  [[tensor(0.4238), tensor(0.0946), tensor(-0.01...  living_40.jpg
# 18  [[tensor(0.1192), tensor(0.1163), tensor(0.000...  living_19.jpg
# 8   [[tensor(0.3475), tensor(-0.0609), tensor(0.04...   living_9.jpg
#
#     clip_similarities
# 35           0.889912
# 26           0.885574
# 39           0.883363
# 18           0.880416
# 8            0.870659

# %%
# draw_images([Image.open(i) for i in top5.img_path.tolist()], top5.img_name.tolist())

# %% [markdown]
# ---

# %% [markdown]
# ### 2. 이미지의 description을 활용한 유사도 탐색

# %% [markdown]
# #### < Text embedding db 추가 >
# - 02.알맞은 embedding model 선택 방법 참고
# - 04.유사도 측정 최적화 참고
#
# #### < Input query 전처리 >
# - GPT-4V를 활용하여 동일한 형태의 image description 생성
# - Text embedding화 하여 기존의 text embedding db와 유사도 측정

# %% [markdown]
# 1-1. Text embedding DB 구축

# %%
df.head(2)
# Out:
#                                    img_path  \
# 0  ../data/room-dataset/living/living_1.jpg
# 1  ../data/room-dataset/living/living_2.jpg
#
#                                              img_emb      img_name  \
# 0  [[tensor(0.5824), tensor(-0.3086), tensor(0.04...  living_1.jpg
# 1  [[tensor(0.1654), tensor(0.1498), tensor(0.052...  living_2.jpg
#
#    clip_similarities
# 0           0.811182
# 1           0.868923

# %%
img_descriptions['living_1.jpg']
# Out:
# {'Color Scheme': 'A warm, earthy color palette dominates the room, with rich brown tones in the wooden beams and furniture. Accents of deep red in the seating enhance the rustic ambiance. Neutral stone gray from the fireplace balances the warmth of the wood tones. Hints of black in the metalwork and chandelier provide contrast.',
#  'Lighting': "Natural light streams in through the windows, adding a bright and airy feel during the day. The large, open fireplace provides a warm glow, contributing to the room's coziness. Ambient light seems to be augmented by hidden fixtures or lamps, not visible in the image.",
#  'Spatial Layout': "Furniture is arranged in a symmetrical layout, with a clear focal point on the fireplace. Seating is oriented to encourage conversation and enjoy the warmth of the fire. The room's space is open and hospitable, with plenty of room for movement and flow.",
#  'Architectural Features': "Exposed heavy timber beams and trusses impart a classic, rustic charm. A loft space overlooks the living area, suggesting additional living or recreational space. The stone fireplace is a grand central feature, extending up to the room's vaulted ceiling. Large windows with wooden frames invite natural light and offer views of the surroundings."}

# %%
img_desc_df = pd.DataFrame(img_descriptions).T.reset_index()
img_desc_df.rename(columns={"index":"img_name"}, inplace=True)

# %%
img_desc_df.head(2)
# Out:
#        img_name                                       Color Scheme  \
# 0  living_1.jpg  A warm, earthy color palette dominates the roo...
# 1  living_2.jpg  Warm, neutral tones predominate, creating a co...
#
#                                             Lighting  \
# 0  Natural light streams in through the windows, ...
# 1  Ample natural light pours in through large win...
#
#                                       Spatial Layout  \
# 0  Furniture is arranged in a symmetrical layout,...
# 1  A casual and comfortable layout is evident wit...
#
#                               Architectural Features
# 0  Exposed heavy timber beams and trusses impart ...
# 1  The space is characterized by a high vaulted c...

# %%
df = df.merge(img_desc_df, on='img_name', how='left')

# %%
df.isna().sum()
# Out:
# img_path                  0
# img_emb                   0
# img_name                  0
# clip_similarities         0
# Color Scheme              0
# Lighting                  0
# Spatial Layout            0
# Architectural Features    0
# dtype: int64

# %%
df.head(2)
# Out:
#                                    img_path  \
# 0  ../data/room-dataset/living/living_1.jpg
# 1  ../data/room-dataset/living/living_2.jpg
#
#                                              img_emb      img_name  \
# 0  [[tensor(0.5824), tensor(-0.3086), tensor(0.04...  living_1.jpg
# 1  [[tensor(0.1654), tensor(0.1498), tensor(0.052...  living_2.jpg
#
#    clip_similarities                                       Color Scheme  \
# 0           0.811182  A warm, earthy color palette dominates the roo...
# 1           0.868923  Warm, neutral tones predominate, creating a co...
#
#                                             Lighting  \
# 0  Natural light streams in through the windows, ...
# 1  Ample natural light pours in through large win...
#
#                                       Spatial Layout  \
# 0  Furniture is arranged in a symmetrical layout,...
# 1  A casual and comfortable layout is evident wit...
#
#                               Architectural Features
# 0  Exposed heavy timber beams and trusses impart ...
# 1  The space is characterized by a high vaulted c...

# %%
from text_utils import create_embeddings

# %%
df['Color Scheme']
# Out:
# 0     A warm, earthy color palette dominates the roo...
# 1     Warm, neutral tones predominate, creating a co...
# 2     A warm and rustic color scheme, dominated by e...
# 3     Neutral and warm color palette, featuring shad...
# 4     The room features a warm, earthy color palette...
#                             ...
# 95    This room has a modern and airy color scheme, ...
# 96    The color scheme features earthy tones with a ...
# 97    A sophisticated palette dominated by the warmt...
# 98    This living room features a warm and earthy co...
# 99    The color scheme is predominantly neutral, wit...
# Name: Color Scheme, Length: 100, dtype: object

# %%
# embedding api를 활용하여 batch로 처리 가능
df['Color Scheme emb'] = create_embeddings(df['Color Scheme'].tolist())
df['Lighting emb'] = create_embeddings(df['Lighting'].tolist())
df['Spatial Layout emb'] = create_embeddings(df['Spatial Layout'].tolist())
df['Architectural Features emb'] = create_embeddings(df['Architectural Features'].tolist())

# %%
# embedding 후 데이터 확인
df.head(2)
# Out:
#                                    img_path  \
# 0  ../data/room-dataset/living/living_1.jpg
# 1  ../data/room-dataset/living/living_2.jpg
#
#                                              img_emb      img_name  \
# 0  [[tensor(0.5824), tensor(-0.3086), tensor(0.04...  living_1.jpg
# 1  [[tensor(0.1654), tensor(0.1498), tensor(0.052...  living_2.jpg
#
#    clip_similarities                                       Color Scheme  \
# 0           0.811182  A warm, earthy color palette dominates the roo...
# 1           0.868923  Warm, neutral tones predominate, creating a co...
#
#                                             Lighting  \
# 0  Natural light streams in through the windows, ...
# 1  Ample natural light pours in through large win...
#
#                                       Spatial Layout  \
# 0  Furniture is arranged in a symmetrical layout,...
# 1  A casual and comfortable layout is evident wit...
#
#                               Architectural Features  \
# 0  Exposed heavy timber beams and trusses impart ...
# 1  The space is characterized by a high vaulted c...
#
#                                     Color Scheme emb  \
# 0  [-0.033221904188394547, 0.012830857187509537, ...
# 1  [-0.004536536522209644, 0.0018330508610233665,...
#
#                                         Lighting emb  \
# 0  [-0.007462856359779835, 0.0008498110109940171,...
# 1  [-0.004978296346962452, -0.008417501114308834,...
#
#                                   Spatial Layout emb  \
# 0  [-0.02039841189980507, -0.002325007924810052, ...
# 1  [-0.007335903588682413, 0.013705400750041008, ...
#
#                           Architectural Features emb
# 0  [0.010061056353151798, 0.027104785665869713, 0...
# 1  [-0.007943094708025455, 0.031397704035043716, ...

# %% [markdown]
# 1-2. Input query 전처리 및 search

# %% [markdown]
# - input query 전처리

# %%
from text_utils import normal_chat_completion

# %%
prompt = """Reformat the input Korean, into a json format like below. The output should be in English.
It should capture information related to 'Color Scheme', 'Lighting', 'Spatial Layout', 'Architectural Features'.
If there is no information related to each category, create one yourself.

Example output:
{'Color Scheme': 'The living room features a neutral color palette with earthy tones. White walls dominate the space, providing a bright and open feel, while furniture pieces in shades of beige, cream, and brown add warmth. Accents of dark wood on the ceiling beams and furniture give the room a rich contrast, and subtle patterns on the upholstery create visual interest without overpowering the space.',
 'Lighting': 'Natural light streams in through the arched windows, illuminating the room and highlighting the indoor greenery. The ceiling pendant and strategically placed floor and table lamps provide additional layers of warm ambient lighting that contribute to the cozy atmosphere.',
 'Spatial Layout': 'The layout is open and inviting, with a central seating area comprised of a large sofa and complementing armchairs facing each other over a leather ottoman that doubles as a coffee table. The arrangement encourages conversation and social interaction. Clear pathways around the furniture make for easy movement through the room.',
 'Architectural Features': "Architectural highlights include the high ceiling adorned with dark wooden beams that add character and a sense of history to the space. The ceiling's design, along with the arched windows and doorways, suggests a Mediterranean or Spanish influence. These features are complemented by a mix of classic and contemporary furniture, creating a timeless look."}

Input Korean:
"""

room_desc = "벽난로가 가운데에 있고, 전체적인 분위기는 어두웠으면 좋겠어. 그리고 나무 탁자가 가운데에 배치되어 있어야 하고, 특색있는 소파들이 주변에 있으면 좋겠어. 두 개는 작은 소파고, 하나는 3인용 소파로. 그리고 주변에 포인트를 줄 수 있는 가구들이 있는 것도 좋아."

# %%
output = normal_chat_completion(prompt + room_desc)

# %%
image_desc = json.loads(output.choices[0].message.content)

# %%
image_desc
# Out:
# {'Color Scheme': 'The overall atmosphere is desired to be dark. This could involve incorporating a color palette that features deeper shades and tones. Darker furniture, such as wooden tables and distinctive sofas, would complement this atmosphere, adding depth and richness to the space.',
#  'Lighting': 'Given the preference for a darker ambiance, lighting would play a key role in balancing visibility with mood. Strategically placed lamps that cast soft, warm glows could illuminate the space without detracting from the desired dark atmosphere. Accent lighting could highlight architectural features and furniture, adding layers of interest.',
#  'Spatial Layout': 'The spatial arrangement centers around a fireplace, suggesting a cozy and intimate setting. A wooden table is placed in the middle of the room, serving as a focal point. Around it, there are special sofas positioned for comfort and aesthetics; two are smaller sofas, and one is a three-seater. This layout is designed to encourage social interactions while providing unique points of interest with additional furniture.',
#  'Architectural Features': 'While not specifically mentioned, the intentional arrangement around a central fireplace suggests the importance of architectural features in the design. This could indicate a preference for traditional or rustic elements, such as exposed brick or stone for the fireplace facade. The mention of distinctive sofas and a central wooden table also hints at a desire for craftsmanship and material quality, which are architectural considerations in their own right.'}

# %%
image_desc_emb = dict()

for k,v in image_desc.items():
    image_desc_emb[k] = create_embeddings(v)[0]

# %%
image_desc_emb
# Out:
# {'Color Scheme': [-0.018734710291028023,
#   -0.002182652708142996,
#   -0.002133419970050454,
#   -0.0007930578431114554,
#   0.01710674539208412,
#   -0.016043318435549736,
#   0.025797970592975616,
#   0.018380234017968178,
#   0.004618033766746521,
#   -0.011625497601926327,
#   -0.01786821335554123,
#   -0.004972509574145079,
#   -0.005786491557955742,
#   -0.03862474858760834,
#   0.04017394036054611,
#   0.05109705030918121,
#   0.052226122468709946,
#   0.01547878235578537,
#   0.008934106677770615,
#   0.001091326354071498,
#   -0.025876743718981743,
#   0.006213160697370768,
#   -0.004616079851984978,
#   0.0193985253572464,
#   -0.05901987478137016,
#   -0.009658047929406166,
#   0.005680800415575504,
#   0.01612880267202854,
#   0.05426641181111336,
#   0.05006248131394386,
#   0.00016797258285805583,
#   -0.019865628331899643,
#   0.0007483097724616528,
#   0.03923667594790459,
#   0.009795431047677994,
#   0.008558981120586395,
#   0.023245258256793022,
#   -0.013738332316279411,
#   -0.021431798115372658,
#   0.001477729412727058,
#   0.03615929186344147,
#   -0.029977040365338326,
#   0.027394235134124756,
#   0.03989611566066742,
#   -0.002838682848960161,
#   -0.010262534022331238,
#   0.010825805366039276,
#   ...]}

# %%
image_desc_emb.keys()
# Out:
# dict_keys(['Color Scheme', 'Lighting', 'Spatial Layout', 'Architectural Features'])

# %% [markdown]
# search

# %%
df['color_sim'] = search_similar_vector(image_desc_emb['Color Scheme'], df['Color Scheme emb'].tolist())
df['lighting_sim'] = search_similar_vector(image_desc_emb['Lighting'], df['Lighting emb'].tolist())
df['layout_sim'] = search_similar_vector(image_desc_emb['Spatial Layout'], df['Spatial Layout emb'].tolist())
df['archi_sim'] = search_similar_vector(image_desc_emb['Architectural Features'], df['Architectural Features emb'].tolist())

# %%
df['desc_similarity'] = df[['color_sim', 'lighting_sim', 'layout_sim', 'archi_sim']].mean(axis=1)

# %%
df.head(2)
# Out:
#                                    img_path  \
# 0  ../data/room-dataset/living/living_1.jpg
# 1  ../data/room-dataset/living/living_2.jpg
#
#                                              img_emb      img_name  \
# 0  [[tensor(0.5824), tensor(-0.3086), tensor(0.04...  living_1.jpg
# 1  [[tensor(0.1654), tensor(0.1498), tensor(0.052...  living_2.jpg
#
#    clip_similarities                                       Color Scheme  \
# 0           0.811182  A warm, earthy color palette dominates the roo...
# 1           0.868923  Warm, neutral tones predominate, creating a co...
#
#                                             Lighting  \
# 0  Natural light streams in through the windows, ...
# 1  Ample natural light pours in through large win...
#
#                                       Spatial Layout  \
# 0  Furniture is arranged in a symmetrical layout,...
# 1  A casual and comfortable layout is evident wit...
#
#                               Architectural Features  \
# 0  Exposed heavy timber beams and trusses impart ...
# 1  The space is characterized by a high vaulted c...
#
#                                     Color Scheme emb  \
# 0  [-0.033221904188394547, 0.012830857187509537, ...
# 1  [-0.004536536522209644, 0.0018330508610233665,...
#
#                                         Lighting emb  \
# 0  [-0.007462856359779835, 0.0008498110109940171,...
# 1  [-0.004978296346962452, -0.008417501114308834,...
#
#                                   Spatial Layout emb  \
# 0  [-0.02039841189980507, -0.002325007924810052, ...
# 1  [-0.007335903588682413, 0.013705400750041008, ...
#
#                           Architectural Features emb  color_sim  lighting_sim  \
# 0  [0.010061056353151798, 0.027104785665869713, 0...   0.677951      0.595164
# 1  [-0.007943094708025455, 0.031397704035043716, ...   0.602000      0.577294
#
#    layout_sim  archi_sim  desc_similarity
# 0    0.818859   0.588077         0.670013
# 1    0.710347   0.621504         0.627787

# %%
img_top5 = df.nlargest(5, 'clip_similarities')
# draw_images([Image.open(i) for i in img_top5['img_path'].tolist()], img_top5.img_name.tolist())

# %%
text_top5 = df.nlargest(5, 'desc_similarity')
# draw_images([Image.open(i) for i in text_top5['img_path'].tolist()], text_top5.img_name.tolist())

# %%
text_top5 = df.nlargest(5, 'layout_sim')
# draw_images([Image.open(i) for i in text_top5['img_path'].tolist()], text_top5.img_name.tolist())

# %%
text_top5 = df.nlargest(5, 'archi_sim')
# draw_images([Image.open(i) for i in text_top5['img_path'].tolist()], text_top5.img_name.tolist())

# %% [markdown]
# - 각 description 별로 원하는 대로 weight를 다르게 줄 수 있음 (similarity의 시각을 다각화)

# %% [markdown]
# ==> Meta data를 활용, 기존의 search space를 줄일 수도 있음

# %%
from collections import Counter

# %%
furniture_descriptions['../data/room-dataset/living/living_1.jpg']
# Out:
# {'boxes': [[0.0, 646.0740966796875, 173.80274963378906, 852.3871459960938],
#   [428.7904968261719, 649.98583984375, 622.0, 855.7733764648438],
#   [420.5445251464844, 803.3565673828125, 621.3555297851562, 930.150146484375],
#   [0.0, 793.6344604492188, 201.38124084472656, 930.3408813476562],
#   [13.38364315032959, 604.041015625, 103.91728973388672, 668.1535034179688]],
#  'scores': [0.9133118391036987,
#   0.9028496742248535,
#   0.7879153490066528,
#   0.7175205945968628,
#   0.6018742918968201],
#  'categories': [57.0, 57.0, 56.0, 56.0, 56.0],
#  'labels': ['couch', 'couch', 'chair', 'chair', 'chair']}

# %%
filter_imgs = list()

for k,v in furniture_descriptions.items():
    counts = Counter(v['labels'])
    if (counts['couch']>=1) and (counts['dining table']>=1):
        filter_imgs.append(k)

# %%
filter_imgs
# Out:
# ['../data/room-dataset/living/living_18.jpg',
#  '../data/room-dataset/living/living_24.jpg',
#  '../data/room-dataset/living/living_51.jpg',
#  '../data/room-dataset/living/living_57.jpeg',
#  '../data/room-dataset/living/living_63.jpg',
#  '../data/room-dataset/living/living_83.jpg',
#  '../data/room-dataset/living/living_89.jpg']

# %%
# draw_images([Image.open(i) for i in filter_imgs])

# %%
df
# Out:
#                                       img_path  \
# 0     ../data/room-dataset/living/living_1.jpg
# 1     ../data/room-dataset/living/living_2.jpg
# 2     ../data/room-dataset/living/living_3.jpg
# 3     ../data/room-dataset/living/living_4.jpg
# 4     ../data/room-dataset/living/living_5.jpg
# ..                                         ...
# 95   ../data/room-dataset/living/living_96.jpg
# 96   ../data/room-dataset/living/living_97.jpg
# 97   ../data/room-dataset/living/living_98.jpg
# 98   ../data/room-dataset/living/living_99.jpg
# 99  ../data/room-dataset/living/living_100.jpg
#
#                                               img_emb        img_name  \
# 0   [[tensor(0.5824), tensor(-0.3086), tensor(0.04...    living_1.jpg
# 1   [[tensor(0.1654), tensor(0.1498), tensor(0.052...    living_2.jpg
# 2   [[tensor(0.1472), tensor(0.0983), tensor(0.261...    living_3.jpg
# 3   [[tensor(0.4033), tensor(-0.0663), tensor(-0.0...    living_4.jpg
# 4   [[tensor(0.7429), tensor(-0.4593), tensor(-0.0...    living_5.jpg
# ..                                                ...             ...
# 95  [[tensor(-0.1111), tensor(-0.0210), tensor(-0....   living_96.jpg
# 96  [[tensor(0.3944), tensor(0.0104), tensor(-0.04...   living_97.jpg
# 97  [[tensor(0.1730), tensor(-0.1309), tensor(0.04...   living_98.jpg
# 98  [[tensor(0.4590), tensor(-0.1097), tensor(-0.0...   living_99.jpg
# 99  [[tensor(0.3656), tensor(-0.0182), tensor(0.27...  living_100.jpg
#
#     clip_similarities                                       Color Scheme  \
# 0            0.811182  A warm, earthy color palette dominates the roo...
# 1            0.868923  Warm, neutral tones predominate, creating a co...
# 2            0.853854  A warm and rustic color scheme, dominated by e...
# 3            0.842833  Neutral and warm color palette, featuring shad...
# 4            0.814352  The room features a warm, earthy color palette...
# ..                ...                                                ...
# 95           0.730477  This room has a modern and airy color scheme, ...
# 96           0.826503  The color scheme features earthy tones with a ...
# 97           0.846395  A sophisticated palette dominated by the warmt...
# 98           0.818847  This living room features a warm and earthy co...
# 99           0.740766  The color scheme is predominantly neutral, wit...
#
#                                              Lighting  \
# 0   Natural light streams in through the windows, ...
# 1   Ample natural light pours in through large win...
# 2   Ambient lighting is achieved through a combina...
# 3   The room benefits from a blend of natural ligh...
# 4   A blend of warm ambient lighting emanates from...
# ..                                                ...
# 95  The room is lit by daylight from multiple wind...
# 96  Natural lighting appears to enter through unse...
# 97  The room is lit by a combination of natural li...
# 98  There is ample natural light streaming in from...
# 99  Natural lighting from the large, floor-to-ceil...
#
#                                        Spatial Layout  \
# 0   Furniture is arranged in a symmetrical layout,...
# 1   A casual and comfortable layout is evident wit...
# 2   The room is arranged for socializing and comfo...
# 3   The living room sports a comfortable and open ...
# 4   The room has an open layout with a high ceilin...
# ..                                                ...
# 95  The layout is open and inviting with a large c...
# 96  The room has an open and airy layout with furn...
# 97  The furniture is strategically placed to encou...
# 98  The living room is designed with an open-conce...
# 99  The room has a minimalist layout with a symmet...
#
#                                Architectural Features  \
# 0   Exposed heavy timber beams and trusses impart ...
# 1   The space is characterized by a high vaulted c...
# 2   Visible log cabin walls and exposed wooden bea...
# 3   Prominent features include a majestic stone fi...
# 4   Distinctive features include the high, vaulted...
# ..                                                ...
# 95  Key architectural features include high ceilin...
# 96  Key architectural features include a vaulted w...
# 97  Architectural features include the prominent e...
# 98  Highlighted architectural features include exp...
# 99  The room boasts a soaring ceiling and industri...
#
#                                      Color Scheme emb  \
# 0   [-0.033221904188394547, 0.012830857187509537, ...
# 1   [-0.004536536522209644, 0.0018330508610233665,...
# 2   [-0.003179720602929592, -0.001857765018939972,...
# 3   [-0.016975821927189827, 0.00891146995127201, 0...
# 4   [-0.03221917897462845, 0.019724424928426743, 0...
# ..                                                ...
# 95  [-0.021414900198578835, -0.0010039964690804482...
# 96  [-0.02592860721051693, 0.007360121235251427, 0...
# 97  [-0.03598788008093834, 0.0007136300555430353, ...
# 98  [-0.04485982283949852, -0.005411298014223576, ...
# 99  [-0.03030003048479557, 0.006710592191666365, 0...
#
#                                          Lighting emb  \
# 0   [-0.007462856359779835, 0.0008498110109940171,...
# 1   [-0.004978296346962452, -0.008417501114308834,...
# 2   [-0.014449937269091606, -0.005502419080585241,...
# 3   [-0.007915140129625797, 0.022174905985593796, ...
# 4   [0.004684414714574814, -0.03707875311374664, 0...
# ..                                                ...
# 95  [-0.004929928574711084, 0.03915826603770256, -...
# 96  [-0.0005582237499766052, -0.012096717022359371...
# 97  [0.00032585783628746867, 0.0005710829864256084...
# 98  [-0.017474234104156494, 0.011390513740479946, ...
# 99  [-0.017385756596922874, -0.008122039958834648,...
#
#                                    Spatial Layout emb  \
# 0   [-0.02039841189980507, -0.002325007924810052, ...
# 1   [-0.007335903588682413, 0.013705400750041008, ...
# 2   [-0.013948089443147182, -0.014244857244193554,...
# 3   [-0.018921315670013428, -0.008999308571219444,...
# 4   [-0.050161976367235184, -0.03144998103380203, ...
# ..                                                ...
# 95  [-0.03192232921719551, -0.015872910618782043, ...
# 96  [-0.02469959482550621, -0.042642392218112946, ...
# 97  [-0.018533889204263687, -0.005728479474782944,...
# 98  [0.0022097264882177114, -0.004353404976427555,...
# 99  [-0.05067881569266319, -0.05279865115880966, 0...
#
#                            Architectural Features emb  color_sim  \
# 0   [0.010061056353151798, 0.027104785665869713, 0...   0.677951
# 1   [-0.007943094708025455, 0.031397704035043716, ...   0.602000
# 2   [-0.019229793921113014, -0.013514107093214989,...   0.555082
# 3   [0.005303000099956989, -0.00019728879851754755...   0.537942
# 4   [-0.04924087971448898, 0.015708064660429955, 0...   0.611834
# ..                                                ...        ...
# 95  [-0.036035194993019104, 0.0066303350031375885,...   0.579796
# 96  [-0.04549068212509155, 0.006918266415596008, 0...   0.595883
# 97  [-0.018484292551875114, 0.023894615471363068, ...   0.626034
# 98  [-0.03918331116437912, 0.0034504791256040335, ...   0.594322
# 99  [-0.05536847934126854, -0.0036764328833669424,...   0.652874
#
#     lighting_sim  layout_sim  archi_sim  desc_similarity
# 0       0.595164    0.818859   0.588077         0.670013
# 1       0.577294    0.710347   0.621504         0.627787
# 2       0.617308    0.682024   0.566459         0.605218
# 3       0.612428    0.721740   0.588258         0.615092
# 4       0.633826    0.760693   0.596856         0.650802
# ..           ...         ...        ...              ...
# 95      0.599457    0.698467   0.521104         0.599706
# 96      0.622207    0.711728   0.517964         0.611945
# 97      0.615629    0.739272   0.648600         0.657384
# 98      0.531340    0.627019   0.540914         0.573399
# 99      0.512868    0.671799   0.456017         0.573389
#
# [100 rows x 17 columns]

# %%
tmp_df = df.loc[df['img_path'].isin(filter_imgs)]

# %%
tmp_df
# Out:
#                                       img_path  \
# 17   ../data/room-dataset/living/living_18.jpg
# 23   ../data/room-dataset/living/living_24.jpg
# 50   ../data/room-dataset/living/living_51.jpg
# 56  ../data/room-dataset/living/living_57.jpeg
# 62   ../data/room-dataset/living/living_63.jpg
# 82   ../data/room-dataset/living/living_83.jpg
# 88   ../data/room-dataset/living/living_89.jpg
#
#                                               img_emb        img_name  \
# 17  [[tensor(0.0095), tensor(0.1380), tensor(-0.15...   living_18.jpg
# 23  [[tensor(0.4510), tensor(-0.0040), tensor(-0.2...   living_24.jpg
# 50  [[tensor(0.0766), tensor(0.3713), tensor(-0.05...   living_51.jpg
# 56  [[tensor(-0.1657), tensor(0.1119), tensor(0.12...  living_57.jpeg
# 62  [[tensor(-0.0310), tensor(0.0955), tensor(-0.0...   living_63.jpg
# 82  [[tensor(-0.2004), tensor(-0.3226), tensor(0.1...   living_83.jpg
# 88  [[tensor(0.6205), tensor(-0.3244), tensor(-0.1...   living_89.jpg
#
#     clip_similarities                                       Color Scheme  \
# 17           0.799234  This living room has a neutral and earthy colo...
# 23           0.866057  The room features natural wood tones from the ...
# 50           0.749705  The room features a warm and neutral color sch...
# 56           0.680557  A palette of neutral colors dominates the room...
# 62           0.680221  Muted and monochromatic with varying shades of...
# 82           0.758537  The room features an industrial color palette ...
# 88           0.758537  This living room employs a warm, industrial co...
#
#                                              Lighting  \
# 17  The room features an elegant black metal chand...
# 23  Ample daylight from the windows and the door b...
# 50  The room benefits from a combination of natura...
# 56  The room is well-lit with a combination of rec...
# 62  Ambient lighting appears warm and subdued, pro...
# 82  Natural light streams in through the large win...
# 88  Natural lighting streams through the tall, arc...
#
#                                        Spatial Layout  \
# 17  The furniture is laid out in a way that center...
# 23  Centered around a prominent stone fireplace, t...
# 50  The living room has an open and airy layout wi...
# 56  The living space is open and flows into the ki...
# 62  Open-plan layout with clear zones for sitting ...
# 82  The room has an open-plan layout with a sectio...
# 88  The room features an open-plan layout with a l...
#
#                                Architectural Features  \
# 17  Prominent architectural features in this room ...
# 23  A cathedral ceiling with exposed beams gives a...
# 50  Notable architectural features include a tall,...
# 56  This modern design boasts floor-to-ceiling gla...
# 62  The room features clean lines with a contrast ...
# 82  Architectural highlights include high ceilings...
# 88  Characterized by its high ceiling with exposed...
#
#                                      Color Scheme emb  \
# 17  [-0.011274517513811588, 0.015261978842318058, ...
# 23  [-0.00976406317204237, 0.015371261164546013, 0...
# 50  [-0.011111419647932053, 0.002341995947062969, ...
# 56  [-0.04412296786904335, -0.02632889151573181, 0...
# 62  [-0.008643853478133678, 0.024371135979890823, ...
# 82  [-0.0532681904733181, -0.005990974139422178, 0...
# 88  [-0.03903529793024063, 0.01644418016076088, 0....
#
#                                          Lighting emb  \
# 17  [-0.0010817520087584853, 0.0030387805309146643...
# 23  [-0.027285154908895493, -0.010922775603830814,...
# 50  [-0.030838388949632645, -0.002758308779448271,...
# 56  [-0.013875027187168598, -0.017479751259088516,...
# 62  [-0.00718813156709075, -0.00671372702345252, 0...
# 82  [-0.008480041287839413, 0.003200890962034464, ...
# 88  [-0.03643203154206276, 0.0071656303480267525, ...
#
#                                    Spatial Layout emb  \
# 17  [-0.029312865808606148, -0.03335262089967728, ...
# 23  [-0.014751920476555824, -0.015090744942426682,...
# 50  [0.0023868982680141926, 0.006615242455154657, ...
# 56  [-0.002760578878223896, -0.02589232660830021, ...
# 62  [-0.04118097573518753, -0.012027154676616192, ...
# 82  [-0.03068552352488041, 0.003901926800608635, 0...
# 88  [-0.0335356779396534, -0.03384378179907799, 0....
#
#                            Architectural Features emb  color_sim  \
# 17  [-0.020331107079982758, -0.0026790087576955557...   0.556601
# 23  [0.0023152169305831194, 0.0026022405363619328,...   0.566633
# 50  [-0.0371539406478405, -0.0008664177148602903, ...   0.630225
# 56  [-0.028159750625491142, -0.03229307010769844, ...   0.602431
# 62  [-0.048244088888168335, -0.0026048331055790186...   0.546252
# 82  [-0.04021496698260307, -0.015765022486448288, ...   0.551974
# 88  [-0.05045977607369423, 0.00656170817092061, 0....   0.583561
#
#     lighting_sim  layout_sim  archi_sim  desc_similarity
# 17      0.542116    0.833885   0.687753         0.655089
# 23      0.584649    0.817497   0.505393         0.618543
# 50      0.600068    0.719755   0.656258         0.651576
# 56      0.595514    0.636688   0.427254         0.565472
# 62      0.660734    0.668980   0.450138         0.581526
# 82      0.486911    0.554834   0.489827         0.520887
# 88      0.569136    0.669042   0.456699         0.569610

# %%
text_top5 = tmp_df.nlargest(5, 'desc_similarity')
# draw_images([Image.open(i) for i in text_top5['img_path'].tolist()], text_top5.img_name.tolist())

# %% [markdown]
# ---

# %% [markdown]
# ### 3. user query에 보인 가구와 유사한 상품 탐색

# %% [markdown]
# #### < 가구 DB 구축 >
# - crop된 이미지들의 embedding vector 생성
#
# #### < 이미지에서 사용된 가구와 유사한 가구 search >
# - Input 이미지의 분위기를 연출하기 위해 필요한 가구들

# %%
furniture_paths[:5]
# Out:
# ['../data/room-dataset/living_cropped/living_100_0.jpg',
#  '../data/room-dataset/living_cropped/living_100_1.jpg',
#  '../data/room-dataset/living_cropped/living_10_0.jpg',
#  '../data/room-dataset/living_cropped/living_10_1.jpg',
#  '../data/room-dataset/living_cropped/living_10_2.jpg']

# %%
furniture_df = pd.DataFrame(furniture_paths)
furniture_df.columns = ['path']
furniture_df['f_img_name'] = furniture_df['path'].str.split('/').str[-1]
furniture_df['original_img'] = furniture_df['f_img_name'].apply(lambda x: "_".join(x.split("_")[:2]))
furniture_df['furniture_id'] = furniture_df['f_img_name'].str.extract(r'_(\d+)\.jpg$')[0]

# %%
furniture_df.head(2)
# Out:
#                                                 path        f_img_name  \
# 0  ../data/room-dataset/living_cropped/living_100...  living_100_0.jpg
# 1  ../data/room-dataset/living_cropped/living_100...  living_100_1.jpg
#
#   original_img furniture_id
# 0   living_100            0
# 1   living_100            1

# %%
furniture_df.sort_values(by=['original_img'])
# Out:
#                                                   path       f_img_name  \
# 36   ../data/room-dataset/living_cropped/living_1_0...   living_1_0.jpg
# 40   ../data/room-dataset/living_cropped/living_1_4...   living_1_4.jpg
# 39   ../data/room-dataset/living_cropped/living_1_3...   living_1_3.jpg
# 38   ../data/room-dataset/living_cropped/living_1_2...   living_1_2.jpg
# 37   ../data/room-dataset/living_cropped/living_1_1...   living_1_1.jpg
# ..                                                 ...              ...
# 288  ../data/room-dataset/living_cropped/living_98_...  living_98_1.jpg
# 289  ../data/room-dataset/living_cropped/living_99_...  living_99_0.jpg
# 290  ../data/room-dataset/living_cropped/living_99_...  living_99_1.jpg
# 291  ../data/room-dataset/living_cropped/living_99_...  living_99_2.jpg
# 292  ../data/room-dataset/living_cropped/living_99_...  living_99_3.jpg
#
#     original_img furniture_id
# 36      living_1            0
# 40      living_1            4
# 39      living_1            3
# 38      living_1            2
# 37      living_1            1
# ..           ...          ...
# 288    living_98            1
# 289    living_99            0
# 290    living_99            1
# 291    living_99            2
# 292    living_99            3
#
# [298 rows x 4 columns]

# %%
furniture_descriptions['../data/room-dataset/living/living_1.jpg']
# Out:
# {'boxes': [[0.0, 646.0740966796875, 173.80274963378906, 852.3871459960938],
#   [428.7904968261719, 649.98583984375, 622.0, 855.7733764648438],
#   [420.5445251464844, 803.3565673828125, 621.3555297851562, 930.150146484375],
#   [0.0, 793.6344604492188, 201.38124084472656, 930.3408813476562],
#   [13.38364315032959, 604.041015625, 103.91728973388672, 668.1535034179688]],
#  'scores': [0.9133118391036987,
#   0.9028496742248535,
#   0.7879153490066528,
#   0.7175205945968628,
#   0.6018742918968201],
#  'categories': [57.0, 57.0, 56.0, 56.0, 56.0],
#  'labels': ['couch', 'couch', 'chair', 'chair', 'chair']}

# %%
furniture_desc_df = pd.DataFrame()

for k,v in furniture_descriptions.items():
    tmp_df = pd.DataFrame(v)
    tmp_df['furniture_id'] = [str(i) for i in list(range(len(tmp_df)))]
    match = re.search(r'(living_\d+)', k)
    f_tmp_df = furniture_df.loc[furniture_df['original_img']==match.group()].sort_values(by='furniture_id')
    if len(f_tmp_df)>0:
        f_tmp_df = f_tmp_df.merge(tmp_df, on='furniture_id', how='left')
        furniture_desc_df = pd.concat([furniture_desc_df, f_tmp_df], axis=0)

# %%
furniture_desc_df.head(2)
# Out:
#                                                 path      f_img_name  \
# 0  ../data/room-dataset/living_cropped/living_1_0...  living_1_0.jpg
# 1  ../data/room-dataset/living_cropped/living_1_1...  living_1_1.jpg
#
#   original_img furniture_id  \
# 0     living_1            0
# 1     living_1            1
#
#                                                boxes    scores  categories  \
# 0  [0.0, 646.0740966796875, 173.80274963378906, 8...  0.913312        57.0
# 1  [428.7904968261719, 649.98583984375, 622.0, 85...  0.902850        57.0
#
#   labels
# 0  couch
# 1  couch

# %% [markdown]
# embedding vector 생성하기

# %%
from transformers import CLIPProcessor, CLIPModel
from utils import extract_img_features

model_name = "openai/clip-vit-base-patch32"
clip_model = CLIPModel.from_pretrained(model_name)
clip_processor = CLIPProcessor.from_pretrained(model_name)

# %%
embeddings = [extract_img_features(Image.open(i), clip_processor, clip_model) for i in furniture_desc_df.path.tolist()]
furniture_desc_df['emb'] = embeddings

# %%
furniture_desc_df.head(2)
# Out:
#                                                 path      f_img_name  \
# 0  ../data/room-dataset/living_cropped/living_1_0...  living_1_0.jpg
# 1  ../data/room-dataset/living_cropped/living_1_1...  living_1_1.jpg
#
#   original_img furniture_id  \
# 0     living_1            0
# 1     living_1            1
#
#                                                boxes    scores  categories  \
# 0  [0.0, 646.0740966796875, 173.80274963378906, 8...  0.913312        57.0
# 1  [428.7904968261719, 649.98583984375, 622.0, 85...  0.902850        57.0
#
#   labels                                                emb
# 0  couch  [[tensor(0.0433), tensor(0.4381), tensor(-0.11...
# 1  couch  [[tensor(0.0147), tensor(0.3773), tensor(0.014...

# %% [markdown]
# 가구 이미지 추출

# %%
from utils import detect_objects, filter_furniture, crop_bbox, normalize_image

import yolov5

# load pretrained model
model = yolov5.load('yolov5s.pt')

# set model parameters
model.conf = 0.3  # NMS confidence threshold
model.iou = 0.45  # NMS IoU threshold
model.agnostic = False  # NMS class-agnostic
model.multi_label = False  # NMS multiple labels per box
model.max_det = 1000  # maximum number of detections per image
# Out:
# YOLOv5  2024-5-17 Python-3.11.9 torch-2.3.0 CUDA:0 (NVIDIA GeForce GTX 1050 Ti, 4096MiB)
#
# Fusing layers...
# YOLOv5s summary: 270 layers, 7235389 parameters, 0 gradients, 16.6 GFLOPs
# Adding AutoShape...

# %%
detect = detect_objects('../data/room-dataset/living/living_212.jpg', model)
detections_parsed = filter_furniture(detect)

# %%
detections_parsed
# Out:
# {'boxes': array([[     412.92,      243.14,      608.75,      345.07],
#         [     47.013,       243.1,      230.05,      342.55],
#         [     327.73,      237.69,      400.43,      321.15],
#         [     3.4639,      306.96,      277.48,      474.85],
#         [     347.93,      361.67,      438.28,      480.29],
#         [     373.33,      289.89,      645.87,      471.65]], dtype=float32),
#  'scores': array([    0.86239,     0.77586,     0.77004,     0.64976,     0.64171,     0.53269], dtype=float32),
#  'categories': array([         57,          57,          56,          57,          56,          56], dtype=float32),
#  'lables': ['couch', 'couch', 'chair', 'couch', 'chair', 'chair']}

# %%
# detect[0].show()

# %%
# detections_parsed
boxes = list()

for b in detections_parsed['boxes']:
    cropped = crop_bbox(query_image, b)
    normalized_image = normalize_image(cropped, target_size=(112, 112))
    boxes.append(normalized_image)

# %%
# %matplotlib inline
draw_images(boxes, detections_parsed['lables']) # dining table or chair?

# %% [markdown]
# 현재 이미지에 있는 가구들과 유사한 가구들을 search

# %%
boxes_emb = [extract_img_features(i, clip_processor, clip_model)[0] for i in boxes]

# %%
search_df = furniture_desc_df[['path', 'f_img_name']]
search_df['table_findings'] = search_similar_vector(boxes_emb[4], furniture_desc_df['emb'].tolist())
search_df['chair_findings'] = search_similar_vector(boxes_emb[5], furniture_desc_df['emb'].tolist())
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_28496\3047397518.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   search_df['table_findings'] = search_similar_vector(boxes_emb[4], furniture_desc_df['emb'].tolist())
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_28496\3047397518.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   search_df['chair_findings'] = search_similar_vector(boxes_emb[5], furniture_desc_df['emb'].tolist())

# %%
search_df.head()
# Out:
#                                                 path      f_img_name  \
# 0  ../data/room-dataset/living_cropped/living_1_0...  living_1_0.jpg
# 1  ../data/room-dataset/living_cropped/living_1_1...  living_1_1.jpg
# 2  ../data/room-dataset/living_cropped/living_1_2...  living_1_2.jpg
# 3  ../data/room-dataset/living_cropped/living_1_3...  living_1_3.jpg
# 4  ../data/room-dataset/living_cropped/living_1_4...  living_1_4.jpg
#
#    table_findings  chair_findings
# 0        0.756738        0.845411
# 1        0.732395        0.854782
# 2        0.818444        0.833346
# 3        0.817024        0.759078
# 4        0.840544        0.743577

# %%
table_top5 = search_df.nlargest(5, 'table_findings')
chair_top5 = search_df.nlargest(5, 'chair_findings')

# %%
draw_images([Image.open(i) for i in table_top5['path']])

# %%
draw_images([Image.open(i) for i in chair_top5['path']])

# %% [markdown]
# - 제품별 이미지 embedding을 통해 cosine similarity를 구하기 위해서는 각 제품이 특정한 상태에서 찍혀있어야함
#   (ex. 각도, 방향 등)
