# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image
import torch
import json
import itertools
from sklearn.metrics.pairwise import cosine_similarity
import os
import openai
from tqdm.notebook import tqdm

from dotenv import load_dotenv
load_dotenv()

pd.set_option('display.max_columns', None)

# %%
from text_utils import create_embeddings

# %%
# initialize openai
openai.api_key = os.environ["OPENAI_API_KEY"]

# %%
# Splade 모델 github에서 다운로드 필요 https://github.com/naver/splade
from splade.splade.models.transformer_rep import Splade
from transformers import AutoTokenizer

sparse_model_id = 'naver/splade-cocondenser-ensembledistil'

# splade = 'naver/splade-v3'
sparse_model = Splade(sparse_model_id, agg='max')
# sparse_model.to('cpu')  # move to GPU if possible
sparse_model.eval()

splade_tokenizer = AutoTokenizer.from_pretrained(sparse_model_id)

# %%
def gen_sparse_vector(text):
    tokens = splade_tokenizer(text, return_tensors="pt", padding=True, truncation=True)

    with torch.no_grad():
        sparse_emb = sparse_model(
            d_kwargs=tokens.to('cpu')
        )['d_rep'].squeeze()

    return sparse_emb

# %%
input_text = "pants"
# input_text = "low waist"
# input_text = "trousers" # (pants의 동의어)

# %%
texts = [
   "pants, silhouette_name : straight, symmetrical,silhouette_fit_name : regular (fit), waistline_name : low waist,",
   "pants, silhouette_name : straight, symmetrical,silhouette_fit_name : regular (fit), geometric pattern",
   "symmetrical, silhouette_fit_name : regular (fit), waistline_name : low waist,",
   "symmetrical, silhouette_fit_name : regular (fit), waistline_name : high waist,"
]

# %%
embs = create_embeddings(texts)
input_emb = create_embeddings([input_text])

print("Dense vector similarities :", cosine_similarity(input_emb, embs))
# Out:
# Dense vector similarities : [[0.42016653 0.43070957 0.31788163 0.31183107]]

# %%
for i in texts:
    print('-', i)

print()
s_embs = [gen_sparse_vector(t).numpy() for t in texts]
input_s_emb = [gen_sparse_vector(input_text).numpy()]

print("Sparse vector similarities :", cosine_similarity(input_s_emb, s_embs))
# Out:
# - pants, silhouette_name : straight, symmetrical,silhouette_fit_name : regular (fit), waistline_name : low waist,
# - pants, silhouette_name : straight, symmetrical,silhouette_fit_name : regular (fit), geometric pattern
# - symmetrical, silhouette_fit_name : regular (fit), waistline_name : low waist,
# - symmetrical, silhouette_fit_name : regular (fit), waistline_name : high waist,
#
# Sparse vector similarities : [[0.4135003  0.43643478 0.0507601  0.05063569]]

# %% [markdown]
# - 각 단어별 weight 살펴보기

# %%
# create the tokens that will be input into the model
tokens = splade_tokenizer(texts[0], return_tensors="pt")
splade_tokenizer.convert_ids_to_tokens(tokens['input_ids'][0])

with torch.no_grad():
    sparse_emb = sparse_model(
        d_kwargs=tokens.to('cpu')
    )['d_rep'].squeeze()
sparse_emb.shape

indices = sparse_emb.nonzero().squeeze().cpu().tolist()
values = sparse_emb[indices].cpu().tolist()

print(len(indices))

idx2token = {idx: token for token, idx in splade_tokenizer.get_vocab().items()}
# Out:
# 92

# %% [markdown]
# "pants, silhouette_name : straight, symmetrical,silhouette_fit_name : regular (fit), waistline_name : low waist,"

# %%
sparse_dict_tokens = {
    idx2token[idx]: round(weight, 2) for idx, weight in zip(indices, values)
}
# sort so we can see most relevant tokens first
sparse_dict_tokens = {
    k: v for k, v in sorted(
        sparse_dict_tokens.items(),
        key=lambda item: item[1],
        reverse=True
    )
}
sparse_dict_tokens
# Out:
# {'silhouette': 2.4,
#  'pants': 1.71,
#  'waist': 1.66,
#  'straight': 1.61,
#  'symmetrical': 1.58,
#  'low': 1.45,
#  'fit': 1.45,
#  'regular': 1.42,
#  'name': 1.3,
#  'jeans': 1.26,
#  'symmetry': 1.19,
#  'trousers': 1.04,
#  '##line': 0.95,
#  'lower': 0.85,
#  'meaning': 0.74,
#  'clothing': 0.72,
#  'names': 0.69,
#  'reynolds': 0.68,
#  'flat': 0.6,
#  '_': 0.57,
#  'shadow': 0.56,
#  'clothes': 0.55,
#  'fitting': 0.47,
#  'shape': 0.46,
#  'definition': 0.46,
#  'webb': 0.45,
#  'word': 0.41,
#  'morris': 0.4,
#  'justin': 0.37,
#  'style': 0.36,
#  'dress': 0.35,
#  'line': 0.34,
#  'design': 0.33,
#  'fashion': 0.33,
#  'belt': 0.3,
#  'jean': 0.29,
#  'gender': 0.29,
#  'sport': 0.28,
#  'photography': 0.27,
#  'logo': 0.27,
#  'named': 0.25,
#  'lowest': 0.25,
#  'zipper': 0.25,
#  'madison': 0.23,
#  'prefix': 0.23,
#  'sex': 0.22,
#  'shoe': 0.22,
#  'quote': 0.21,
#  '##tour': 0.21,
#  'image': 0.2,
#  'clark': 0.19,
#  'math': 0.19,
#  'torso': 0.18,
#  'abbreviation': 0.16,
#  'symbol': 0.15,
#  'simon': 0.14,
#  'kelly': 0.14,
#  'print': 0.14,
#  'thomas': 0.13,
#  'sizes': 0.13,
#  'underwear': 0.13,
#  'taylor': 0.12,
#  'adam': 0.12,
#  'jordan': 0.12,
#  'fred': 0.12,
#  'socks': 0.11,
#  'wright': 0.1,
#  'bradley': 0.1,
#  'matt': 0.09,
#  'parker': 0.08,
#  'shame': 0.08,
#  'blade': 0.07,
#  'graphic': 0.07,
#  'position': 0.06,
#  'fabric': 0.06,
#  'zip': 0.05,
#  'detail': 0.04,
#  'arnold': 0.04,
#  'geometric': 0.04,
#  'crotch': 0.04,
#  'joe': 0.03,
#  'benjamin': 0.03,
#  'comfortable': 0.03,
#  'symmetric': 0.03,
#  'foot': 0.02,
#  'spencer': 0.02,
#  'shorts': 0.02,
#  'burke': 0.02,
#  'color': 0.01,
#  'knee': 0.01,
#  'hart': 0.01,
#  'levi': 0.01}

# %% [markdown]
# ## sparse vector
#
# 예시
# - document :
#
# ```json
# silhouette_name : symmetrical,
# silhouette_fit_name : regular (fit),
# waistline_name : low waist,
# length_name : maxi (length),
# opening_type_name : fly (opening),
# non-textile material type_name : no non-textile material
# ```

# %%
def listify(string, encap_type="()"):
    return [int(num) for num in string.strip(encap_type).split(', ')]

# %%
attributes = pd.read_csv("../data/imaterialist-fashion-2020-fgvc7/attribute_specific.csv")
new_df = pd.read_csv("../data/imaterialist-fashion-2020-fgvc7/clothes_final2.csv")

new_df['bbox'] = [listify(i, "[]") for i in new_df['bbox']]
new_df['bbox_big'] = [listify(i, "[]") for i in new_df['bbox_big']]

# %%
new_df.head(2)
# Out:
#    entity_id                           ImageId  \
# 0          0  00000663ed1ff0c4e0132b9b9ac53f6e
# 1          1  00000663ed1ff0c4e0132b9b9ac53f6e
#
#                                        EncodedPixels  Height  Width  ClassId  \
# 0  6068157 7 6073371 20 6078584 34 6083797 48 608...    5214   3676        6
# 1  6323163 11 6328356 32 6333549 53 6338742 75 63...    5214   3676        0
#
#                      AttributesIds second_AttributesIds  \
# 0  115,136,143,154,230,295,316,317                  NaN
# 1  115,136,142,146,225,295,316,317                  163
#
#                        bbox                  bbox_big  width  height     area  \
# 0  [1163, 3923, 2839, 5212]  [1122, 3891, 2880, 5214]   1758    1323  2325834
# 1  [1212, 1371, 2394, 3978]  [1183, 1306, 2423, 4043]   1240    2737  3393880
#
#    id           name supercategory  \
# 0   6          pants     lowerbody
# 1   0  shirt, blouse     upperbody
#
#                                      AttributesNames second_AttributesNames
# 0  symmetrical, regular (fit), low waist, maxi (l...                    NaN
# 1  symmetrical, regular (fit), normal waist, abov...         shirt (collar)

# %%
new_df['name'].unique()
# Out:
# array(['pants', 'shirt, blouse', 'jacket', 'top, t-shirt, sweatshirt',
#        'dress', 'shoe', 'glasses', 'skirt', 'bag, wallet', 'belt',
#        'headband, head covering, hair accessory', 'sock', 'hat', 'watch',
#        'glove', 'tights, stockings', 'sweater', 'tie', 'shorts', 'scarf',
#        'coat', 'vest', 'umbrella', 'cardigan', 'cape', 'jumpsuit',
#        'leg warmer'], dtype=object)

# %% [markdown]
# ### 1. 각 supercategory 별로 group
#
# #### Supercategory 별로 attribute를 구분하기

# %% [markdown]
# - 조금 더 자세히 살펴보면, 우리들이 갖고 있는 attribute은 몇 가지 레벨로 나눌 수 있다
# 	- 가장 큰 단위는 당연히 classID - 바지, 상의, 신발 등
# 	- 더 세밀하게 나눠보면 classID에 따른 특징들을 그룹화 할 수 있다
# 		- 하위 attribute들은 각자 다른 특징을 나타낸다
# 		- 핏감, 전체적인 옷의 형태, 질감, 마감, 길이 등
# 		- 따라서 이런 attribute들을 모두 각자의 그룹에 맞게 고려되어야 한다

# %%
attributes.head(3)
# Out:
#    id               name supercategory  level supercategory2   taxonomy_id
# 0   0  classic (t-shirt)      nickname      1  main_category  att000002_00
# 1   1       polo (shirt)      nickname      1  main_category  att000003_00
# 2   2         undershirt      nickname      1  main_category  att000004_00

# %%
attributes['supercategory2'].unique()
# Out:
# array(['main_category', 'silhouette', 'silhouette_fit', 'waistline',
#        'length', 'collar_type', 'neckline_type', 'sleeve_type',
#        'pocket_type', 'opening_type', 'non-textile material type',
#        'leather', 'textile finishing, manufacturing techniques',
#        'textile pattern', 'animal', 'other'], dtype=object)

# %% [markdown]
# 아무런 attribute이 없는 항목은 'normal'이라는 attribute을 임의로 부여

# %%
new_df.loc[new_df['AttributesIds'].isna(), 'AttributesIds'] = "999"
new_df.loc[new_df['AttributesNames'].isna(), 'AttributesNames'] = "normal"

# %%
new_df.tail(2)
# Out:
#        entity_id                           ImageId  \
# 97922      97922  fffe20b555b98c3c1f26c8dfff275cbc
# 97923      97923  ffffbf7014a9e408bfbb81a75bc70638
#
#                                            EncodedPixels  Height  Width  \
# 97922  2446541 2 2449539 5 2452536 10 2455534 14 2458...    3000   2001
# 97923  63365 36 63852 77 64343 85 64838 89 65332 94 6...     500    375
#
#        ClassId                    AttributesIds second_AttributesIds  \
# 97922        0  115,136,142,146,225,295,316,322          204,160,163
# 97923       10      102,128,142,150,295,308,317                  157
#
#                          bbox                bbox_big  width  height    area  \
# 97922  [815, 640, 1128, 1576]  [808, 617, 1135, 1599]    327     982  321114
# 97923    [126, 115, 297, 442]    [122, 107, 301, 450]    179     343   61397
#
#        id           name supercategory  \
# 97922   0  shirt, blouse     upperbody
# 97923  10          dress     wholebody
#
#                                          AttributesNames  \
# 97922  symmetrical, regular (fit), normal waist, abov...
# 97923  sheath (dress), straight, normal waist, above-...
#
#                             second_AttributesNames
# 97922  set-in sleeve, wrist-length, shirt (collar)
# 97923                               short (length)

# %% [markdown]
# - Main attribute과 secondary attribute들을 하나로 묶음
#     - 이는 supercategory2를 임의로 지정하여 sleeve, collar들에 해당하는 attribute ID를 별도로 처리할 수 있기 때문

# %%
def merge_columns(row):
    # Check if either value is np.nan and return the other value in such cases
    if pd.isna(row['AttributesIds']) and not pd.isna(row['second_AttributesIds']):
        return row['second_AttributesIds']
    elif not pd.isna(row['AttributesIds']) and pd.isna(row['second_AttributesIds']):
        return row['AttributesIds']
    elif pd.isna(row['AttributesIds']) and pd.isna(row['second_AttributesIds']):
        return np.nan
    else:
        # Both values are not np.nan, merge with a comma
        return f"{row['AttributesIds']},{row['second_AttributesIds']}"

new_df['AttributesIds_merged'] = new_df.apply(merge_columns, axis=1)

# %%
new_df.head(2)
# Out:
#    entity_id                           ImageId  \
# 0          0  00000663ed1ff0c4e0132b9b9ac53f6e
# 1          1  00000663ed1ff0c4e0132b9b9ac53f6e
#
#                                        EncodedPixels  Height  Width  ClassId  \
# 0  6068157 7 6073371 20 6078584 34 6083797 48 608...    5214   3676        6
# 1  6323163 11 6328356 32 6333549 53 6338742 75 63...    5214   3676        0
#
#                      AttributesIds second_AttributesIds  \
# 0  115,136,143,154,230,295,316,317                  NaN
# 1  115,136,142,146,225,295,316,317                  163
#
#                        bbox                  bbox_big  width  height     area  \
# 0  [1163, 3923, 2839, 5212]  [1122, 3891, 2880, 5214]   1758    1323  2325834
# 1  [1212, 1371, 2394, 3978]  [1183, 1306, 2423, 4043]   1240    2737  3393880
#
#    id           name supercategory  \
# 0   6          pants     lowerbody
# 1   0  shirt, blouse     upperbody
#
#                                      AttributesNames second_AttributesNames  \
# 0  symmetrical, regular (fit), low waist, maxi (l...                    NaN
# 1  symmetrical, regular (fit), normal waist, abov...         shirt (collar)
#
#                   AttributesIds_merged
# 0      115,136,143,154,230,295,316,317
# 1  115,136,142,146,225,295,316,317,163

# %%
def convert2list(string):
    if pd.isna(string):
        return np.nan
    else:
        return list(set([i for i in string.split(',')]))

new_df['AttributesIds_list'] = new_df['AttributesIds_merged'].apply(convert2list)

# %%
new_df.head(2)
# Out:
#    entity_id                           ImageId  \
# 0          0  00000663ed1ff0c4e0132b9b9ac53f6e
# 1          1  00000663ed1ff0c4e0132b9b9ac53f6e
#
#                                        EncodedPixels  Height  Width  ClassId  \
# 0  6068157 7 6073371 20 6078584 34 6083797 48 608...    5214   3676        6
# 1  6323163 11 6328356 32 6333549 53 6338742 75 63...    5214   3676        0
#
#                      AttributesIds second_AttributesIds  \
# 0  115,136,143,154,230,295,316,317                  NaN
# 1  115,136,142,146,225,295,316,317                  163
#
#                        bbox                  bbox_big  width  height     area  \
# 0  [1163, 3923, 2839, 5212]  [1122, 3891, 2880, 5214]   1758    1323  2325834
# 1  [1212, 1371, 2394, 3978]  [1183, 1306, 2423, 4043]   1240    2737  3393880
#
#    id           name supercategory  \
# 0   6          pants     lowerbody
# 1   0  shirt, blouse     upperbody
#
#                                      AttributesNames second_AttributesNames  \
# 0  symmetrical, regular (fit), low waist, maxi (l...                    NaN
# 1  symmetrical, regular (fit), normal waist, abov...         shirt (collar)
#
#                   AttributesIds_merged  \
# 0      115,136,143,154,230,295,316,317
# 1  115,136,142,146,225,295,316,317,163
#
#                               AttributesIds_list
# 0       [317, 154, 316, 136, 295, 230, 115, 143]
# 1  [146, 225, 317, 163, 316, 136, 295, 115, 142]

# %% [markdown]
# #### 각 attribute들을 분류하여 각 컬럼에 배치
# - `attributes`를 참고하며, 각 attribute ID를 attribute name으로 변환

# %%
attributes.head(2)
# Out:
#    id               name supercategory  level supercategory2   taxonomy_id
# 0   0  classic (t-shirt)      nickname      1  main_category  att000002_00
# 1   1       polo (shirt)      nickname      1  main_category  att000003_00

# %%
attributes['id'] = attributes['id'].astype(str)

# Create a mapping of id to supercategory2
id_to_supercategory2 = attributes.set_index('id')['supercategory2'].to_dict()

# %%
id_to_supercategory2
# Out:
# {'0': 'main_category',
#  '1': 'main_category',
#  '2': 'main_category',
#  '3': 'main_category',
#  '4': 'main_category',
#  '5': 'main_category',
#  '6': 'main_category',
#  '7': 'main_category',
#  '8': 'main_category',
#  '9': 'main_category',
#  '10': 'main_category',
#  '11': 'main_category',
#  '12': 'main_category',
#  '13': 'main_category',
#  '14': 'main_category',
#  '15': 'main_category',
#  '16': 'main_category',
#  '17': 'main_category',
#  '18': 'main_category',
#  '19': 'main_category',
#  '20': 'main_category',
#  '21': 'main_category',
#  '22': 'main_category',
#  '23': 'main_category',
#  '24': 'main_category',
#  '25': 'main_category',
#  '26': 'main_category',
#  '27': 'main_category',
#  '28': 'main_category',
#  '29': 'main_category',
#  '30': 'main_category',
#  '31': 'main_category',
#  '32': 'main_category',
#  '33': 'main_category',
#  '34': 'main_category',
#  '35': 'main_category',
#  '36': 'main_category',
#  '37': 'main_category',
#  '38': 'main_category',
#  '39': 'main_category',
#  '40': 'main_category',
#  '41': 'main_category',
#  '42': 'main_category',
#  '43': 'main_category',
#  '44': 'main_category',
#  '45': 'main_category',
#  '46': 'main_category',
#  '47': 'main_category',
#  '48': 'main_category',
#  '49': 'main_category',
#  '50': 'main_category',
#  '51': 'main_category',
#  '52': 'main_category',
#  '53': 'main_category',
#  '54': 'main_category',
#  '55': 'main_category',
#  '56': 'main_category',
#  '57': 'main_category',
#  '58': 'main_category',
#  '59': 'main_category',
#  '60': 'main_category',
#  '61': 'main_category',
#  '62': 'main_category',
#  '63': 'main_category',
#  '64': 'main_category',
#  '65': 'main_category',
#  '66': 'main_category',
#  '67': 'main_category',
#  '68': 'main_category',
#  '69': 'main_category',
#  '70': 'main_category',
#  '71': 'main_category',
#  '72': 'main_category',
#  '73': 'main_category',
#  '74': 'main_category',
#  '75': 'main_category',
#  '76': 'main_category',
#  '77': 'main_category',
#  '78': 'main_category',
#  '79': 'main_category',
#  '80': 'main_category',
#  '81': 'main_category',
#  '82': 'main_category',
#  '83': 'main_category',
#  '84': 'main_category',
#  '85': 'main_category',
#  '86': 'main_category',
#  '87': 'main_category',
#  '88': 'main_category',
#  '89': 'main_category',
#  '90': 'main_category',
#  '91': 'main_category',
#  '92': 'main_category',
#  '93': 'main_category',
#  '94': 'main_category',
#  '95': 'main_category',
#  '96': 'main_category',
#  '97': 'main_category',
#  '98': 'main_category',
#  '99': 'main_category',
#  '100': 'main_category',
#  '101': 'main_category',
#  '102': 'main_category',
#  '103': 'main_category',
#  '104': 'main_category',
#  '105': 'main_category',
#  '106': 'main_category',
#  '107': 'main_category',
#  '108': 'main_category',
#  '109': 'main_category',
#  '110': 'main_category',
#  '111': 'main_category',
#  '112': 'main_category',
#  '113': 'main_category',
#  '114': 'silhouette',
#  '115': 'silhouette',
#  '116': 'silhouette',
#  '117': 'silhouette',
#  '118': 'silhouette',
#  '119': 'silhouette',
#  '120': 'silhouette',
#  '121': 'silhouette',
#  '122': 'silhouette',
#  '123': 'silhouette',
#  '124': 'silhouette',
#  '125': 'silhouette',
#  '126': 'silhouette',
#  '127': 'silhouette',
#  '128': 'silhouette',
#  '129': 'silhouette',
#  '130': 'silhouette',
#  '131': 'silhouette',
#  '132': 'silhouette',
#  '133': 'silhouette',
#  '134': 'silhouette_fit',
#  '135': 'silhouette_fit',
#  '136': 'silhouette_fit',
#  '137': 'silhouette_fit',
#  '138': 'silhouette_fit',
#  '139': 'waistline',
#  '140': 'waistline',
#  '141': 'waistline',
#  '142': 'waistline',
#  '143': 'waistline',
#  '144': 'waistline',
#  '145': 'waistline',
#  '146': 'length',
#  '147': 'length',
#  '148': 'length',
#  '149': 'length',
#  '150': 'length',
#  '151': 'length',
#  '152': 'length',
#  '153': 'length',
#  '154': 'length',
#  '155': 'length',
#  '156': 'length',
#  '157': 'length',
#  '158': 'length',
#  '159': 'length',
#  '160': 'length',
#  '161': 'collar_type',
#  '162': 'collar_type',
#  '163': 'collar_type',
#  '164': 'collar_type',
#  '165': 'collar_type',
#  '166': 'collar_type',
#  '167': 'collar_type',
#  '168': 'collar_type',
#  '169': 'collar_type',
#  '170': 'collar_type',
#  '171': 'collar_type',
#  '172': 'collar_type',
#  '173': 'collar_type',
#  '174': 'collar_type',
#  '175': 'collar_type',
#  '176': 'collar_type',
#  '177': 'collar_type',
#  '178': 'collar_type',
#  '179': 'neckline_type',
#  '180': 'neckline_type',
#  '181': 'neckline_type',
#  '182': 'neckline_type',
#  '183': 'neckline_type',
#  '184': 'neckline_type',
#  '185': 'neckline_type',
#  '186': 'neckline_type',
#  '187': 'neckline_type',
#  '188': 'neckline_type',
#  '189': 'neckline_type',
#  '190': 'neckline_type',
#  '191': 'neckline_type',
#  '192': 'neckline_type',
#  '193': 'neckline_type',
#  '194': 'neckline_type',
#  '195': 'neckline_type',
#  '196': 'neckline_type',
#  '197': 'neckline_type',
#  '198': 'neckline_type',
#  '199': 'neckline_type',
#  '200': 'neckline_type',
#  '201': 'neckline_type',
#  '202': 'neckline_type',
#  '203': 'neckline_type',
#  '204': 'sleeve_type',
#  '205': 'sleeve_type',
#  '206': 'sleeve_type',
#  '207': 'sleeve_type',
#  '208': 'sleeve_type',
#  '209': 'sleeve_type',
#  '210': 'sleeve_type',
#  '211': 'sleeve_type',
#  '212': 'sleeve_type',
#  '213': 'sleeve_type',
#  '214': 'sleeve_type',
#  '215': 'sleeve_type',
#  '216': 'sleeve_type',
#  '217': 'pocket_type',
#  '218': 'pocket_type',
#  '219': 'pocket_type',
#  '220': 'pocket_type',
#  '221': 'pocket_type',
#  '222': 'pocket_type',
#  '223': 'pocket_type',
#  '224': 'pocket_type',
#  '225': 'opening_type',
#  '226': 'opening_type',
#  '227': 'opening_type',
#  '228': 'opening_type',
#  '229': 'opening_type',
#  '230': 'opening_type',
#  '231': 'opening_type',
#  '232': 'opening_type',
#  '233': 'opening_type',
#  '234': 'opening_type',
#  '281': 'non-textile material type',
#  '282': 'non-textile material type',
#  '283': 'non-textile material type',
#  '285': 'non-textile material type',
#  '286': 'non-textile material type',
#  '287': 'non-textile material type',
#  '288': 'non-textile material type',
#  '289': 'non-textile material type',
#  '290': 'leather',
#  '291': 'leather',
#  '292': 'leather',
#  '293': 'leather',
#  '294': 'non-textile material type',
#  '295': 'non-textile material type',
#  '296': 'textile finishing, manufacturing techniques',
#  '297': 'textile finishing, manufacturing techniques',
#  '298': 'textile finishing, manufacturing techniques',
#  '299': 'textile finishing, manufacturing techniques',
#  '300': 'textile finishing, manufacturing techniques',
#  '301': 'textile finishing, manufacturing techniques',
#  '302': 'textile finishing, manufacturing techniques',
#  '303': 'textile finishing, manufacturing techniques',
#  '304': 'textile finishing, manufacturing techniques',
#  '305': 'textile finishing, manufacturing techniques',
#  '306': 'textile finishing, manufacturing techniques',
#  '307': 'textile finishing, manufacturing techniques',
#  '308': 'textile finishing, manufacturing techniques',
#  '309': 'textile finishing, manufacturing techniques',
#  '310': 'textile finishing, manufacturing techniques',
#  '311': 'textile finishing, manufacturing techniques',
#  '312': 'textile finishing, manufacturing techniques',
#  '313': 'textile finishing, manufacturing techniques',
#  '314': 'textile finishing, manufacturing techniques',
#  '315': 'textile finishing, manufacturing techniques',
#  '316': 'textile finishing, manufacturing techniques',
#  '317': 'textile pattern',
#  '318': 'textile pattern',
#  '319': 'textile pattern',
#  '320': 'textile pattern',
#  '321': 'textile pattern',
#  '322': 'textile pattern',
#  '323': 'textile pattern',
#  '324': 'textile pattern',
#  '325': 'textile pattern',
#  '326': 'textile pattern',
#  '327': 'textile pattern',
#  '328': 'textile pattern',
#  '329': 'textile pattern',
#  '330': 'textile pattern',
#  '331': 'textile pattern',
#  '332': 'textile pattern',
#  '333': 'animal',
#  '334': 'animal',
#  '335': 'animal',
#  '336': 'animal',
#  '337': 'animal',
#  '338': 'animal',
#  '339': 'textile pattern',
#  '340': 'textile pattern',
#  '999': 'other'}

# %%
# 각 카테고리별로 list를 만든다
category_distributions = list()

# row를 루프를 돌면서 각 dictionary value에 채워 넣는다
for idx, row in tqdm(new_df.iterrows()):
    tmp_dict = {k:'' for k in attributes['supercategory2'].unique()}
    for attr in row['AttributesIds_list']:
        supercat_type = id_to_supercategory2[attr]
        if tmp_dict[supercat_type]=='':
            tmp_dict[supercat_type] += attr
        else:
            tmp_dict[supercat_type] += "," + attr
        # break
    category_distributions.append(tmp_dict)
# Out:
# 0it [00:00, ?it/s]

# %%
category_distributions[0]
# Out:
# {'main_category': '',
#  'silhouette': '115',
#  'silhouette_fit': '136',
#  'waistline': '143',
#  'length': '154',
#  'collar_type': '',
#  'neckline_type': '',
#  'sleeve_type': '',
#  'pocket_type': '',
#  'opening_type': '230',
#  'non-textile material type': '295',
#  'leather': '',
#  'textile finishing, manufacturing techniques': '316',
#  'textile pattern': '317',
#  'animal': '',
#  'other': ''}

# %%
# 각 dictionary를 dataframe 형태로 변환
category_dist_df = [pd.DataFrame([d]) for d in category_distributions]
# list of dataframe을 하나의 dataframe으로 concat
category_dist_df = pd.concat(category_dist_df, axis=0)
# reset index
category_dist_df.reset_index(inplace=True, drop=True)

category_dist_df = category_dist_df.replace('', np.nan)

# %%
category_dist_df.tail()
# Out:
#       main_category silhouette silhouette_fit waistline   length collar_type  \
# 97919           NaN        NaN            NaN       NaN      NaN         NaN
# 97920           NaN        NaN            NaN       NaN      NaN         NaN
# 97921            36    128,115            136       142      154         NaN
# 97922           NaN        115            136       142  146,160         163
# 97923           102        128            NaN       142  157,150         NaN
#
#       neckline_type sleeve_type pocket_type opening_type  \
# 97919           NaN         NaN         NaN          NaN
# 97920           NaN         NaN         NaN          NaN
# 97921           NaN         NaN         NaN          230
# 97922           NaN         204         NaN          225
# 97923           NaN         NaN         NaN          NaN
#
#       non-textile material type leather  \
# 97919                       NaN     NaN
# 97920                       NaN     NaN
# 97921                       295     NaN
# 97922                       295     NaN
# 97923                       295     NaN
#
#       textile finishing, manufacturing techniques textile pattern animal other
# 97919                                         NaN             NaN    NaN   999
# 97920                                         NaN             NaN    NaN   999
# 97921                                         298             317    NaN   NaN
# 97922                                         316             322    NaN   NaN
# 97923                                         308             317    NaN   NaN

# %% [markdown]
# - 기존의 데이터셋과 결합

# %%
new_df = pd.concat([new_df, category_dist_df], axis=1)
new_df = new_df.replace('', np.nan)
new_df.head()
# Out:
#    entity_id                           ImageId  \
# 0          0  00000663ed1ff0c4e0132b9b9ac53f6e
# 1          1  00000663ed1ff0c4e0132b9b9ac53f6e
# 2          2  00000663ed1ff0c4e0132b9b9ac53f6e
# 3          3  0000fe7c9191fba733c8a69cfaf962b7
# 4          4  0002ec21ddb8477e98b2cbb87ea2e269
#
#                                        EncodedPixels  Height  Width  ClassId  \
# 0  6068157 7 6073371 20 6078584 34 6083797 48 608...    5214   3676        6
# 1  6323163 11 6328356 32 6333549 53 6338742 75 63...    5214   3676        0
# 2  4566382 8 4571592 25 4576803 41 4582013 58 458...    5214   3676        4
# 3  1343707 9 1346138 27 1348569 44 1351000 62 135...    2448   2448        1
# 4  2287509 4 2290504 12 2290588 26 2293501 18 229...    3000   1997       10
#
#                         AttributesIds second_AttributesIds  \
# 0     115,136,143,154,230,295,316,317                  NaN
# 1     115,136,142,146,225,295,316,317                  163
# 2  17,115,136,145,149,225,295,311,317      219,204,160,174
# 3           0,115,145,146,295,316,317                  190
# 4     102,128,142,150,229,295,301,318                  182
#
#                        bbox                  bbox_big  width  height     area  \
# 0  [1163, 3923, 2839, 5212]  [1122, 3891, 2880, 5214]   1758    1323  2325834
# 1  [1212, 1371, 2394, 3978]  [1183, 1306, 2423, 4043]   1240    2737  3393880
# 2   [875, 1437, 3309, 4871]   [815, 1352, 3369, 4956]   2554    3604  9204616
# 3    [548, 405, 1946, 2263]    [514, 359, 1980, 2309]   1466    1950  2858700
# 4    [762, 719, 1262, 1967]    [750, 688, 1274, 1998]    524    1310   686440
#
#    id                      name supercategory  \
# 0   6                     pants     lowerbody
# 1   0             shirt, blouse     upperbody
# 2   4                    jacket     upperbody
# 3   1  top, t-shirt, sweatshirt     upperbody
# 4  10                     dress     wholebody
#
#                                      AttributesNames  \
# 0  symmetrical, regular (fit), low waist, maxi (l...
# 1  symmetrical, regular (fit), normal waist, abov...
# 2  blazer, symmetrical, regular (fit), no waistli...
# 3  classic (t-shirt), symmetrical, no waistline, ...
# 4  sheath (dress), straight, normal waist, above-...
#
#                               second_AttributesNames  \
# 0                                                NaN
# 1                                     shirt (collar)
# 2  welt (pocket), set-in sleeve, wrist-length, no...
# 3                                       scoop (neck)
# 4                                       round (neck)
#
#                                 AttributesIds_merged  \
# 0                    115,136,143,154,230,295,316,317
# 1                115,136,142,146,225,295,316,317,163
# 2  17,115,136,145,149,225,295,311,317,219,204,160...
# 3                      0,115,145,146,295,316,317,190
# 4                102,128,142,150,229,295,301,318,182
#
#                                   AttributesIds_list main_category silhouette  \
# 0           [317, 154, 316, 136, 295, 230, 115, 143]           NaN        115
# 1      [146, 225, 317, 163, 316, 136, 295, 115, 142]           NaN        115
# 2  [225, 317, 219, 204, 149, 17, 160, 145, 311, 1...            17        115
# 3             [146, 115, 317, 190, 316, 145, 295, 0]             0        115
# 4      [318, 128, 182, 229, 102, 301, 295, 142, 150]           102        128
#
#   silhouette_fit waistline   length collar_type neckline_type sleeve_type  \
# 0            136       143      154         NaN           NaN         NaN
# 1            136       142      146         163           NaN         NaN
# 2            136       145  149,160         174           NaN         204
# 3            NaN       145      146         NaN           190         NaN
# 4            NaN       142      150         NaN           182         NaN
#
#   pocket_type opening_type non-textile material type leather  \
# 0         NaN          230                       295     NaN
# 1         NaN          225                       295     NaN
# 2         219          225                       295     NaN
# 3         NaN          NaN                       295     NaN
# 4         NaN          229                       295     NaN
#
#   textile finishing, manufacturing techniques textile pattern animal other
# 0                                         316             317    NaN   NaN
# 1                                         316             317    NaN   NaN
# 2                                         311             317    NaN   NaN
# 3                                         316             317    NaN   NaN
# 4                                         301             318    NaN   NaN

# %% [markdown]
# ### 2. 하나의 document로 변환

# %%
category_dist_df.head()
# Out:
#   main_category silhouette silhouette_fit waistline   length collar_type  \
# 0           NaN        115            136       143      154         NaN
# 1           NaN        115            136       142      146         163
# 2            17        115            136       145  149,160         174
# 3             0        115            NaN       145      146         NaN
# 4           102        128            NaN       142      150         NaN
#
#   neckline_type sleeve_type pocket_type opening_type  \
# 0           NaN         NaN         NaN          230
# 1           NaN         NaN         NaN          225
# 2           NaN         204         219          225
# 3           190         NaN         NaN          NaN
# 4           182         NaN         NaN          229
#
#   non-textile material type leather  \
# 0                       295     NaN
# 1                       295     NaN
# 2                       295     NaN
# 3                       295     NaN
# 4                       295     NaN
#
#   textile finishing, manufacturing techniques textile pattern animal other
# 0                                         316             317    NaN   NaN
# 1                                         316             317    NaN   NaN
# 2                                         311             317    NaN   NaN
# 3                                         316             317    NaN   NaN
# 4                                         301             318    NaN   NaN

# %%
id_to_name = pd.Series(attributes.name.values, index=attributes.id).to_dict()

# Define a function to convert IDs to names
def ids_to_names(ids, id_to_name=id_to_name):
    if pd.isna(ids):
        return np.nan
    names = [id_to_name.get(id_, 'Unknown') for id_ in ids.split(',')]
    return ', '.join(names)


for col in category_dist_df.columns:
    if 'name' not in col:
        category_dist_df[col+"_name"] = category_dist_df[col].apply(ids_to_names)

# %%
category_dist_df.head(2)
# Out:
#   main_category silhouette silhouette_fit waistline length collar_type  \
# 0           NaN        115            136       143    154         NaN
# 1           NaN        115            136       142    146         163
#
#   neckline_type sleeve_type pocket_type opening_type  \
# 0           NaN         NaN         NaN          230
# 1           NaN         NaN         NaN          225
#
#   non-textile material type leather  \
# 0                       295     NaN
# 1                       295     NaN
#
#   textile finishing, manufacturing techniques textile pattern animal other  \
# 0                                         316             317    NaN   NaN
# 1                                         316             317    NaN   NaN
#
#   main_category_name silhouette_name silhouette_fit_name waistline_name  \
# 0                NaN     symmetrical       regular (fit)      low waist
# 1                NaN     symmetrical       regular (fit)   normal waist
#
#               length_name collar_type_name neckline_type_name  \
# 0           maxi (length)              NaN                NaN
# 1  above-the-hip (length)   shirt (collar)                NaN
#
#   sleeve_type_name pocket_type_name opening_type_name  \
# 0              NaN              NaN     fly (opening)
# 1              NaN              NaN   single breasted
#
#   non-textile material type_name leather_name  \
# 0        no non-textile material          NaN
# 1        no non-textile material          NaN
#
#   textile finishing, manufacturing techniques_name textile pattern_name  \
# 0               no special manufacturing technique      plain (pattern)
# 1               no special manufacturing technique      plain (pattern)
#
#   animal_name other_name
# 0         NaN        NaN
# 1         NaN        NaN

# %%
# human-readable한 값들로 변환된 컬럼들을 활용
named_df = category_dist_df[[i for i in category_dist_df.columns if '_name' in i]]

# 각 row 별로 하나의 string 값으로 변환
def row_to_string(row):
    return ',\n'.join([f"{col} : {row[col]}" for col in named_df.columns if pd.notna(row[col])])

# Applying the function to each row of the DataFrame and storing the results in a list
list_of_strings = named_df.apply(row_to_string, axis=1).tolist()

# %%
print(list_of_strings[0])
# Out:
# silhouette_name : symmetrical,
# silhouette_fit_name : regular (fit),
# waistline_name : low waist,
# length_name : maxi (length),
# opening_type_name : fly (opening),
# non-textile material type_name : no non-textile material,
# textile finishing, manufacturing techniques_name : no special manufacturing technique,
# textile pattern_name : plain (pattern)

# %%
new_df['doc'] = list_of_strings

# %%
new_df.head(2)
# Out:
#    entity_id                           ImageId  \
# 0          0  00000663ed1ff0c4e0132b9b9ac53f6e
# 1          1  00000663ed1ff0c4e0132b9b9ac53f6e
#
#                                        EncodedPixels  Height  Width  ClassId  \
# 0  6068157 7 6073371 20 6078584 34 6083797 48 608...    5214   3676        6
# 1  6323163 11 6328356 32 6333549 53 6338742 75 63...    5214   3676        0
#
#                      AttributesIds second_AttributesIds  \
# 0  115,136,143,154,230,295,316,317                  NaN
# 1  115,136,142,146,225,295,316,317                  163
#
#                        bbox                  bbox_big  width  height     area  \
# 0  [1163, 3923, 2839, 5212]  [1122, 3891, 2880, 5214]   1758    1323  2325834
# 1  [1212, 1371, 2394, 3978]  [1183, 1306, 2423, 4043]   1240    2737  3393880
#
#    id           name supercategory  \
# 0   6          pants     lowerbody
# 1   0  shirt, blouse     upperbody
#
#                                      AttributesNames second_AttributesNames  \
# 0  symmetrical, regular (fit), low waist, maxi (l...                    NaN
# 1  symmetrical, regular (fit), normal waist, abov...         shirt (collar)
#
#                   AttributesIds_merged  \
# 0      115,136,143,154,230,295,316,317
# 1  115,136,142,146,225,295,316,317,163
#
#                               AttributesIds_list main_category silhouette  \
# 0       [317, 154, 316, 136, 295, 230, 115, 143]           NaN        115
# 1  [146, 225, 317, 163, 316, 136, 295, 115, 142]           NaN        115
#
#   silhouette_fit waistline length collar_type neckline_type sleeve_type  \
# 0            136       143    154         NaN           NaN         NaN
# 1            136       142    146         163           NaN         NaN
#
#   pocket_type opening_type non-textile material type leather  \
# 0         NaN          230                       295     NaN
# 1         NaN          225                       295     NaN
#
#   textile finishing, manufacturing techniques textile pattern animal other  \
# 0                                         316             317    NaN   NaN
# 1                                         316             317    NaN   NaN
#
#                                                  doc
# 0  silhouette_name : symmetrical,\nsilhouette_fit...
# 1  silhouette_name : symmetrical,\nsilhouette_fit...

# %%
new_df.head(2)
# Out:
#    entity_id                           ImageId  \
# 0          0  00000663ed1ff0c4e0132b9b9ac53f6e
# 1          1  00000663ed1ff0c4e0132b9b9ac53f6e
#
#                                        EncodedPixels  Height  Width  ClassId  \
# 0  6068157 7 6073371 20 6078584 34 6083797 48 608...    5214   3676        6
# 1  6323163 11 6328356 32 6333549 53 6338742 75 63...    5214   3676        0
#
#                      AttributesIds second_AttributesIds  \
# 0  115,136,143,154,230,295,316,317                  NaN
# 1  115,136,142,146,225,295,316,317                  163
#
#                        bbox                  bbox_big  width  height     area  \
# 0  [1163, 3923, 2839, 5212]  [1122, 3891, 2880, 5214]   1758    1323  2325834
# 1  [1212, 1371, 2394, 3978]  [1183, 1306, 2423, 4043]   1240    2737  3393880
#
#    id           name supercategory  \
# 0   6          pants     lowerbody
# 1   0  shirt, blouse     upperbody
#
#                                      AttributesNames second_AttributesNames  \
# 0  symmetrical, regular (fit), low waist, maxi (l...                    NaN
# 1  symmetrical, regular (fit), normal waist, abov...         shirt (collar)
#
#                   AttributesIds_merged  \
# 0      115,136,143,154,230,295,316,317
# 1  115,136,142,146,225,295,316,317,163
#
#                               AttributesIds_list main_category silhouette  \
# 0       [317, 154, 316, 136, 295, 230, 115, 143]           NaN        115
# 1  [146, 225, 317, 163, 316, 136, 295, 115, 142]           NaN        115
#
#   silhouette_fit waistline length collar_type neckline_type sleeve_type  \
# 0            136       143    154         NaN           NaN         NaN
# 1            136       142    146         163           NaN         NaN
#
#   pocket_type opening_type non-textile material type leather  \
# 0         NaN          230                       295     NaN
# 1         NaN          225                       295     NaN
#
#   textile finishing, manufacturing techniques textile pattern animal other  \
# 0                                         316             317    NaN   NaN
# 1                                         316             317    NaN   NaN
#
#                                                  doc
# 0  silhouette_name : symmetrical,\nsilhouette_fit...
# 1  silhouette_name : symmetrical,\nsilhouette_fit...

# %%
# # 로컬에 저장
# new_df.to_csv("../data/imaterialist-fashion-2020-fgvc7/clothes_final_sparse_doc.csv", index=False)

# %%
base_path = "../data/imaterialist-fashion-2020-fgvc7/cropped_images/"

new_df['img_path'] = base_path + new_df['ImageId'].astype(str) + "_" + new_df['entity_id'].astype(str) + ".jpg"
# image df와의 join을 위한 키 생성
new_df['img_id'] = new_df['ImageId'].astype(str) + "_" + new_df['entity_id'].astype(str)

# %%
new_df.loc[2022, 'img_path']

Image.open("../data/imaterialist-fashion-2020-fgvc7/train/054f0ae9527a9a79a4de6f3acc166e5b.jpg")

# %%
i = 2020
print(new_df.loc[i, 'name'])
print(new_df.loc[i, 'doc'])
Image.open(new_df.loc[i, 'img_path'])

# %%
i = 2022
print(new_df.loc[i, 'name'])
print(new_df.loc[i, 'doc'])
Image.open(new_df.loc[i, 'img_path'])

# %% [markdown]
# ---

# %%
new_df = pd.read_csv("../data/imaterialist-fashion-2020-fgvc7/clothes_final_sparse_doc.csv")
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_21432\501273952.py:1: DtypeWarning: Columns (23,34) have mixed types. Specify dtype option on import or set low_memory=False.
#   new_df = pd.read_csv("../data/imaterialist-fashion-2020-fgvc7/clothes_final_sparse_doc.csv")

# %% [markdown]
# ### 이미지 embeddings와 함께 merge하여 하나의 dataframe으로 결합

# %%
embeddings = {}

with open('../data/imaterialist-fashion-2020-fgvc7/img_embeddings_fashion_fine_tuned.json', 'r') as file:
    for line in file:
        # Convert each line to a dictionary
        embedding_dict = json.loads(line.strip())
        
        # Convert the list back to a NumPy array if necessary
        for img_name, emb_list in embedding_dict.items():
            embeddings[img_name] = np.array(emb_list)

image_embedddings = pd.DataFrame([embeddings]).T.reset_index()
image_embedddings.rename(columns={"index":"img_id", 0:"img_emb"}, inplace=True)

# %%
image_embedddings.head(2)
# Out:
#                                img_id  \
# 0  00000663ed1ff0c4e0132b9b9ac53f6e_0
# 1  00000663ed1ff0c4e0132b9b9ac53f6e_1
#
#                                              img_emb
# 0  [0.20991066098213196, 0.8551046848297119, -0.1...
# 1  [0.005228467285633087, 0.6059291362762451, -1....

# %%
new_df['img_id'] = new_df['ImageId'].astype(str) + "_" + new_df['entity_id'].astype(str)

# %%
new_df = pd.merge(new_df, image_embedddings, on='img_id', how='left')

# %%
# 모두 잘 join 되었는지 확인
new_df.img_emb.isna().sum()
# Out:
# 0

# %% [markdown]
# ### 3. CLIP : SPLADE = Dense : sparse vector

# %% [markdown]
# - hybrid search를 위해서는 dense vector와 sparse vector를 짝을 지어줘야 함

# %%
from splade.splade.models.transformer_rep import Splade
from transformers import AutoTokenizer

sparse_model_id = 'naver/splade-cocondenser-ensembledistil'

# splade = 'naver/splade-v3'
sparse_model = Splade(sparse_model_id, agg='max')
sparse_model.to('cpu')  # move to GPU if possible
sparse_model.eval()

splade_tokenizer = AutoTokenizer.from_pretrained(sparse_model_id)

# %% [markdown]
# ### 4. pineconeDB upsert 형태로 변환
#
# #### Upsert 형식
#
# ```json
# {"id" : "0838a48a7b0bfa789a5181ab0e8f4ee2_3040", # 이미지 파일 이름 + entity ID
#  "values" : [-0.08405803143978119, -0.7088879346847534, ...], # CLIP embeddings
#  "sparse_values" : {
#     "indices" : [1045, 1062, ...], # non-zero index
#     "values" : [1.3038887977600098, 0.304147332906723, ...] # non-zero values
#     },
# "metadata" : {
#     # 이미지 파일 path
#     "img_path": "../data/imaterialist-fashion-2020-fgvc7/cropped_images/0838a48a7b0bfa789a5181ab0e8f4ee2_3040.jpg",
#     "category": "coat"
# }
# }
#
# ```

# %%
def gen_sparse_vector(text):
    tokens = splade_tokenizer(text, return_tensors="pt", padding=True, truncation=True)

    with torch.no_grad():
        sparse_emb = sparse_model(
            d_kwargs=tokens.to('cpu')
        )['d_rep'].squeeze()
    
    indices = sparse_emb.nonzero().squeeze().cpu().tolist()
    values = sparse_emb[indices].cpu().tolist()

    return indices, values

def upsert_format(id, text, img_emb):
    index, value = gen_sparse_vector(text)
    
    sparse_values = {
        "indices": index,
        "values": value
    }
    
    upsert = {
        "id": id,
        "values": img_emb,
        "sparse_values":sparse_values,
        "metadata":{"img_path":"../data/imaterialist-fashion-2020-fgvc7/cropped_images/"+id+".jpg"}
    }
    return upsert

# %%
tmp = new_df.head(5)

# %%
upserts = list()

for _, row in tqdm(tmp.iterrows(), total=tmp.shape[0]):
    upserts.append(upsert_format(row['img_id'], row['doc'], row['img_emb'].tolist()))

# %%
type(upserts[0]['values'])

# %%
type(upserts[0]['sparse_values'])

# %%
upserts[0]['sparse_values'].keys()

# %%
upserts[0].keys()

# %%
upserts[0]['id']

# %%
upserts[0]['metadata']

# %%
upserts[0]['sparse_values'].keys()

# %% [markdown]
# `02. generate_SPLADE_embeddings.ipynb` 참고

# %% [markdown]
# ### 만들어진 sparse vector 읽어오기

# %%
data_read = []

# Open the file in read mode
with open("../data/imaterialist-fashion-2020-fgvc7/upsert_vectors_fashion_fine_tuned.json", 'r') as file:
    # Iterate through each line in the file
    for line in file:
        # Parse the JSON string into a Python dictionary
        data = json.loads(line)
        # Append the dictionary to the list
        data_read.append(data)

# Now, data_read contains all the dictionaries read from the file
print(f"Successfully read {len(data_read)} items from upsert_vectors_fashion_fine_tuned.json")
# Out:
# Successfully read 97924 items from upsert_vectors_fashion_fine_tuned.json

# %%
data_read[0].keys()
# Out:
# dict_keys(['id', 'values', 'sparse_values', 'metadata'])

# %%
data_read[0]['metadata']
# Out:
# {'img_path': 'imaterialist-fashion-2020-fgvc7/cropped_images/00000663ed1ff0c4e0132b9b9ac53f6e_0.jpg'}
